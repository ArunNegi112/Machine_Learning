# %% [markdown]
# ### What is Early Stopping?
# A regularization technique, that stops the training when signs of overfitting appears.
# A point where loss on training data keeps on decreasing but loss on validation data starts increasing.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Benefits:
# - Reduces overfitting
# - Saves computational power
# - Improves efficiency

# %% [markdown]
# ### Limitations
#
# - Risk of Underfitting: Stopping too early may lead to underfitting where the model doesn't fully learn the patterns in the data. This results in poor generalization.
# - Not Suitable for All Models: Early stopping is not beneficial for every type of model. Complex models may require more extensive training to achieve optimal performance, making early stopping less effective.
# - Dependency on the Validation Set: A poorly chosen or small validation set may fail to accurately indicate when to stop, leading to suboptimal performance.

# %% [markdown]
# ### Implementation

# %% [markdown]
# - Early stopping in machine learning models are model specific.
# - Not all models support early stopping
#     - Models that do not:
#         - RandomForest, DecisionTrees, LinearRegression
#     - Models that do:
#         - SGDReg, SGDClassifier

# %% [markdown]
# Sample code:
# ```python
# model = SGDRegressor(
#     max_iter=1000,
#     tol=1e-3,              # stopping criterion
#     early_stopping=True,   # enable early stopping
#     validation_fraction=0.1,
#     n_iter_no_change=5
# )
